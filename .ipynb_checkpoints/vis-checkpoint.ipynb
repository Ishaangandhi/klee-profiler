# %%
import pandas as pd
import  matplotlib.pyplot as plt
import seaborn as sn

# %%
runstats_df = pd.read_csv("logs/log1.csv")

# %%
runstats_df = runstats_df.loc[:, (runstats_df != 0).any(axis=0)]

# %%
runstats_df
# Out:
#     Instructions  FullBranches  PartialBranches  NumBranches  UserTime  \
# 0            204             1                2            4    6694.0
# 1            204             1                2            4    9723.0
# 2            204             1                2            4   15745.0
# 3            204             1                2            4   14246.0
# 4            204             1                2            4   10710.0
# 5            204             1                2            4    3915.0
# 6            204             1                2            4   15609.0
# 7            204             1                2            4   20927.0
# 8            204             1                2            4    4968.0
# 9            204             1                2            4   10458.0
# 10           204             1                2            4   24815.0
# 11           204             1                2            4   24667.0
# 12           204             1                2            4    8693.0
# 13           204             1                2            4    8289.0
# 14           204             1                2            4   10030.0
#
#     MallocUsage  NumQueries  NumQueryConstructs  WallTime  \
# 0       1819624           2                  14   67410.0
# 1       1819624           2                  14   71844.0
# 2       1819624           2                  14   72058.0
# 3       1819624           2                  14   70093.0
# 4       1819624           2                  14   70604.0
# 5       1819624           2                  14   70229.0
# 6       1819624           2                  14   70482.0
# 7       1819624           2                  14   70300.0
# 8       1819624           2                  14   72369.0
# 9       1819624           2                  14   68874.0
# 10      1819624           2                  14   70430.0
# 11      1819624           2                  14   71480.0
# 12      1819624           2                  14   70774.0
# 13      1819624           2                  14   69452.0
# 14      1819624           2                  14   73498.0
#
#     CoveredInstructions  ...  QueryCexCacheHits  Breaks  Returns  Adds  \
# 0                    39  ...                 -1      42        2    20
# 1                    39  ...                 -1      42        2    20
# 2                    39  ...                 -1      42        2    20
# 3                    39  ...                 -1      42        2    20
# 4                    39  ...                 -1      42        2    20
# 5                    39  ...                 -1      42        2    20
# 6                    39  ...                 -1      42        2    20
# 7                    39  ...                 -1      42        2    20
# 8                    39  ...                 -1      42        2    20
# 9                    39  ...                 -1      42        2    20
# 10                   39  ...                 -1      42        2    20
# 11                   39  ...                 -1      42        2    20
# 12                   39  ...                 -1      42        2    20
# 13                   39  ...                 -1      42        2    20
# 14                   39  ...                 -1      42        2    20
#
#     Allocas  Loads  Stores  BitCasts  ICmps  Calls
# 0         5     73      24         1     31      6
# 1         5     73      24         1     31      6
# 2         5     73      24         1     31      6
# 3         5     73      24         1     31      6
# 4         5     73      24         1     31      6
# 5         5     73      24         1     31      6
# 6         5     73      24         1     31      6
# 7         5     73      24         1     31      6
# 8         5     73      24         1     31      6
# 9         5     73      24         1     31      6
# 10        5     73      24         1     31      6
# 11        5     73      24         1     31      6
# 12        5     73      24         1     31      6
# 13        5     73      24         1     31      6
# 14        5     73      24         1     31      6
#
# [15 rows x 26 columns]

# %%
corrMatrix = runstats_df.corr()
plt.figure(figsize = (16,16))
sn.heatmap(corrMatrix, annot=True)

# %%
corrMatrix = runstats_df.corr()
plt.figure(figsize = (16,5))
sn.heatmap(corrMatrix, annot=True)
